# %% [markdown]
# # Using data below find the maximum salary

# %%
import pandas as pd
data = {
    "Employee": ['E1', 'E2', 'E3', 'E4'],
    "Salary": [50000, 80000, 90000, 60000]
}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Employee  Salary
# 0       E1   50000
# 1       E2   80000
# 2       E3   90000
# 3       E4   60000

# %%
print(df["Salary"].max())
# Out:
# 90000
